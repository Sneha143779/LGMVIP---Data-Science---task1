# %%
import pandas as pd
from IPython.display import display
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\\Users\HP\\Desktop\\LGMVIP Task1\\iris.csv")

# %%
data.head()
# Out:
#    id  sepallength  sepalwidth  petallength  petalwidth        class
# 0   1          5.1         3.5          1.4         0.2  Iris-setosa
# 1   2          4.9         3.0          1.4         0.2  Iris-setosa
# 2   3          4.7         3.2          1.3         0.2  Iris-setosa
# 3   4          4.6         3.1          1.5         0.2  Iris-setosa
# 4   5          5.0         3.6          1.4         0.2  Iris-setosa

# %%
data.sample(10)
# Out:
#       id  sepallength  sepalwidth  petallength  petalwidth            class
# 25    26          5.0         3.0          1.6         0.2      Iris-setosa
# 126  127          6.2         2.8          4.8         1.8   Iris-virginica
# 116  117          6.5         3.0          5.5         1.8   Iris-virginica
# 124  125          6.7         3.3          5.7         2.1   Iris-virginica
# 93    94          5.0         2.3          3.3         1.0  Iris-versicolor
# 67    68          5.8         2.7          4.1         1.0  Iris-versicolor
# 92    93          5.8         2.6          4.0         1.2  Iris-versicolor
# 42    43          4.4         3.2          1.3         0.2      Iris-setosa
# 21    22          5.1         3.7          1.5         0.4      Iris-setosa
# 148  149          6.2         3.4          5.4         2.3   Iris-virginica

# %%
data.columns
# Out:
# Index(['id', 'sepallength', 'sepalwidth', 'petallength', 'petalwidth',
#        'class'],
#       dtype='object')

# %%
data.shape
# Out:
# (150, 6)

# %%
print(data)
# Out:
#       id  sepallength  sepalwidth  petallength  petalwidth           class
# 0      1          5.1         3.5          1.4         0.2     Iris-setosa
# 1      2          4.9         3.0          1.4         0.2     Iris-setosa
# 2      3          4.7         3.2          1.3         0.2     Iris-setosa
# 3      4          4.6         3.1          1.5         0.2     Iris-setosa
# 4      5          5.0         3.6          1.4         0.2     Iris-setosa
# ..   ...          ...         ...          ...         ...             ...
# 145  146          6.7         3.0          5.2         2.3  Iris-virginica
# 146  147          6.3         2.5          5.0         1.9  Iris-virginica
# 147  148          6.5         3.0          5.2         2.0  Iris-virginica
# 148  149          6.2         3.4          5.4         2.3  Iris-virginica
# 149  150          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
#data[start:end]
#start is inclusive whereas end is exclusive 
print(data[10:21])
#it will print the row from 10 to 20

#you can also save it in a variable for further use in analysis
sliced_data=data[10:21]
print(sliced_data)
# Out:
#     id  sepallength  sepalwidth  petallength  petalwidth        class
# 10  11          5.4         3.7          1.5         0.2  Iris-setosa
# 11  12          4.8         3.4          1.6         0.2  Iris-setosa
# 12  13          4.8         3.0          1.4         0.1  Iris-setosa
# 13  14          4.3         3.0          1.1         0.1  Iris-setosa
# 14  15          5.8         4.0          1.2         0.2  Iris-setosa
# 15  16          5.7         4.4          1.5         0.4  Iris-setosa
# 16  17          5.4         3.9          1.3         0.4  Iris-setosa
# 17  18          5.1         3.5          1.4         0.3  Iris-setosa
# 18  19          5.7         3.8          1.7         0.3  Iris-setosa
# 19  20          5.1         3.8          1.5         0.3  Iris-setosa
# 20  21          5.4         3.4          1.7         0.2  Iris-setosa
#     id  sepallength  sepalwidth  petallength  petalwidth        class
# 10  11          5.4         3.7          1.5         0.2  Iris-setosa
# 11  12          4.8         3.4          1.6         0.2  Iris-setosa
# 12  13          4.8         3.0          1.4         0.1  Iris-setosa
# 13  14          4.3         3.0          1.1         0.1  Iris-setosa
# 14  15          5.8         4.0          1.2         0.2  Iris-setosa
# 15  16          5.7         4.4          1.5         0.4  Iris-setosa
# 16  17          5.4         3.9          1.3         0.4  Iris-setosa
# 17  18          5.1         3.5          1.4         0.3  Iris-setosa
# 18  19          5.7         3.8          1.7         0.3  Iris-setosa
# 19  20          5.1         3.8          1.5         0.3  Iris-setosa
# 20  21          5.4         3.4          1.7         0.2  Iris-setosa

# %%
#here in the case of iris dataset
#we will save it in a another variable named"specific_data"

specific_data=data[["id","class"]]
#data[["column_name1","column_name2","column_name3"]]

#now we will print the first 10 columns of the specific_data dataframe
print(specific_data.head(10))
# Out:
#    id        class
# 0   1  Iris-setosa
# 1   2  Iris-setosa
# 2   3  Iris-setosa
# 3   4  Iris-setosa
# 4   5  Iris-setosa
# 5   6  Iris-setosa
# 6   7  Iris-setosa
# 7   8  Iris-setosa
# 8   9  Iris-setosa
# 9  10  Iris-setosa

# %%
data.iloc[5]
data.loc[data["class"] == "iris-setosa"]
# Out:
# Empty DataFrame
# Columns: [id, sepallength, sepalwidth, petallength, petalwidth, class]
# Index: []

# %%
data["class"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: class, dtype: int64

# %%
#data["column_name"].sum()

sum_data = data["sepallength"].sum()
mean_data = data["sepallength"].mean()
median_data = data["sepallength"].median()
print("sum:",sum_data, "\nMean:", mean_data, "\nMedian:", median_data )
# Out:
# sum: 876.5
# Mean: 5.843333333333335
# Median: 5.8

# %%
min_data = data["sepallength"].min()
max_data = data["sepallength"].max()

print("Minimum:",min_data, "\nMaximum:", max_data)
# Out:
# Minimum: 4.3
# Maximum: 7.9

# %%
cols=data.columns
print(cols)
cols = cols[1:5]

data1= data[cols]

data["total_values"]=data1[cols].sum(axis=1)
# Out:
# Index(['id', 'sepallength', 'sepalwidth', 'petallength', 'petalwidth', 'class',
#        'total_values'],
#       dtype='object')

# %%
newcolas={
    "id":"id",
    "sepallength" : "sepallengthCm",
    "sepalwidth" : "sepalwedithCm"
}

data.rename(columns=newcolas, inplace=True)

print(data.head())
# Out:
#    id  sepallengthCm  sepalwedithCm  petallength  petalwidth        class  \
# 0   1            5.1            3.5          1.4         0.2  Iris-setosa
# 1   2            4.9            3.0          1.4         0.2  Iris-setosa
# 2   3            4.7            3.2          1.3         0.2  Iris-setosa
# 3   4            4.6            3.1          1.5         0.2  Iris-setosa
# 4   5            5.0            3.6          1.4         0.2  Iris-setosa
#
#    total_values
# 0          10.2
# 1           9.5
# 2           9.4
# 3           9.4
# 4          10.2

# %%
data.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_51061_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >sepallengthCm</th>
#       <th class="col_heading level0 col2" >sepalwedithCm</th>
#       <th class="col_heading level0 col3" >petallength</th>
#       <th class="col_heading level0 col4" >petalwidth</th>
#       <th class="col_heading level0 col5" >class</th>
#       <th class="col_heading level0 col6" >total_values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51061_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_51061_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_51061_row0_col1" class="data row0 col1" >5.100000</td>
#       <td id="T_51061_row0_col2" class="data row0 col2" >3.500000</td>
#       <td id="T_51061_row0_col3" class="data row0 col3" >1.400000</td>
#       <td id="T_51061_row0_col4" class="data row0 col4" >0.200000</td>
#       <td id="T_51061_row0_col5" class="data row0 col5" >Iris-setosa</td>
#       <td id="T_51061_row0_col6" class="data row0 col6" >10.200000</td>
#     </tr>
#     <tr>
#       <th id="T_51061_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_51061_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_51061_row1_col1" class="data row1 col1" >4.900000</td>
#       <td id="T_51061_row1_col2" class="data row1 col2" >3.000000</td>
#       <td id="T_51061_row1_col3" class="data row1 col3" >1.400000</td>
#       <td id="T_51061_row1_col4" class="data row1 col4" >0.200000</td>
#       <td id="T_51061_row1_col5" class="data row1 col5" >Iris-setosa</td>
#       <td id="T_51061_row1_col6" class="data row1 col6" >9.500000</td>
#     </tr>
#     <tr>
#       <th id="T_51061_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_51061_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_51061_row2_col1" class="data row2 col1" >4.700000</td>
#       <td id="T_51061_row2_col2" class="data row2 col2" >3.200000</td>
#       <td id="T_51061_row2_col3" class="data row2 col3" >1.300000</td>
#       <td id="T_51061_row2_col4" class="data row2 col4" >0.200000</td>
#       <td id="T_51061_row2_col5" class="data row2 col5" >Iris-setosa</td>
#       <td id="T_51061_row2_col6" class="data row2 col6" >9.400000</td>
#     </tr>
#     <tr>
#       <th id="T_51061_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_51061_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_51061_row3_col1" class="data row3 col1" >4.600000</td>
#       <td id="T_51061_row3_col2" class="data row3 col2" >3.100000</td>
#       <td id="T_51061_row3_col3" class="data row3 col3" >1.500000</td>
#       <td id="T_51061_row3_col4" class="data row3 col4" >0.200000</td>
#       <td id="T_51061_row3_col5" class="data row3 col5" >Iris-setosa</td>
#       <td id="T_51061_row3_col6" class="data row3 col6" >9.400000</td>
#     </tr>
#     <tr>
#       <th id="T_51061_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_51061_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_51061_row4_col1" class="data row4 col1" >5.000000</td>
#       <td id="T_51061_row4_col2" class="data row4 col2" >3.600000</td>
#       <td id="T_51061_row4_col3" class="data row4 col3" >1.400000</td>
#       <td id="T_51061_row4_col4" class="data row4 col4" >0.200000</td>
#       <td id="T_51061_row4_col5" class="data row4 col5" >Iris-setosa</td>
#       <td id="T_51061_row4_col6" class="data row4 col6" >10.200000</td>
#     </tr>
#     <tr>
#       <th id="T_51061_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_51061_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_51061_row5_col1" class="data row5 col1" >5.400000</td>
#       <td id="T_51061_row5_col2" class="data row5 col2" >3.900000</td>
#       <td id="T_51061_row5_col3" class="data row5 col3" >1.700000</td>
#       <td id="T_51061_row5_col4" class="data row5 col4" >0.400000</td>
#       <td id="T_51061_row5_col5" class="data row5 col5" >Iris-setosa</td>
#       <td id="T_51061_row5_col6" class="data row5 col6" >11.400000</td>
#     </tr>
#     <tr>
#       <th id="T_51061_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_51061_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_51061_row6_col1" class="data row6 col1" >4.600000</td>
#       <td id="T_51061_row6_col2" class="data row6 col2" >3.400000</td>
#       <td id="T_51061_row6_col3" class="data row6 col3" >1.400000</td>
#       <td id="T_51061_row6_col4" class="data row6 col4" >0.300000</td>
#       <td id="T_51061_row6_col5" class="data row6 col5" >Iris-setosa</td>
#       <td id="T_51061_row6_col6" class="data row6 col6" >9.700000</td>
#     </tr>
#     <tr>
#       <th id="T_51061_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_51061_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_51061_row7_col1" class="data row7 col1" >5.000000</td>
#       <td id="T_51061_row7_col2" class="data row7 col2" >3.400000</td>
#       <td id="T_51061_row7_col3" class="data row7 col3" >1.500000</td>
#       <td id="T_51061_row7_col4" class="data row7 col4" >0.200000</td>
#       <td id="T_51061_row7_col5" class="data row7 col5" >Iris-setosa</td>
#       <td id="T_51061_row7_col6" class="data row7 col6" >10.100000</td>
#     </tr>
#     <tr>
#       <th id="T_51061_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_51061_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_51061_row8_col1" class="data row8 col1" >4.400000</td>
#       <td id="T_51061_row8_col2" class="data row8 col2" >2.900000</td>
#       <td id="T_51061_row8_col3" class="data row8 col3" >1.400000</td>
#       <td id="T_51061_row8_col4" class="data row8 col4" >0.200000</td>
#       <td id="T_51061_row8_col5" class="data row8 col5" >Iris-setosa</td>
#       <td id="T_51061_row8_col6" class="data row8 col6" >8.900000</td>
#     </tr>
#     <tr>
#       <th id="T_51061_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_51061_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_51061_row9_col1" class="data row9 col1" >4.900000</td>
#       <td id="T_51061_row9_col2" class="data row9 col2" >3.100000</td>
#       <td id="T_51061_row9_col3" class="data row9 col3" >1.500000</td>
#       <td id="T_51061_row9_col4" class="data row9 col4" >0.100000</td>
#       <td id="T_51061_row9_col5" class="data row9 col5" >Iris-setosa</td>
#       <td id="T_51061_row9_col6" class="data row9 col6" >9.600000</td>
#     </tr>
#     <tr>
#       <th id="T_51061_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_51061_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_51061_row10_col1" class="data row10 col1" >5.400000</td>
#       <td id="T_51061_row10_col2" class="data row10 col2" >3.700000</td>
#       <td id="T_51061_row10_col3" class="data row10 col3" >1.500000</td>
#       <td id="T_51061_row10_col4" class="data row10 col4" >0.200000</td>
#       <td id="T_51061_row10_col5" class="data row10 col5" >Iris-setosa</td>
#       <td id="T_51061_row10_col6" class="data row10 col6" >10.800000</td>
#     </tr>
#     <tr>
#       <th id="T_51061_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_51061_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_51061_row11_col1" class="data row11 col1" >4.800000</td>
#       <td id="T_51061_row11_col2" class="data row11 col2" >3.400000</td>
#       <td id="T_51061_row11_col3" class="data row11 col3" >1.600000</td>
#       <td id="T_51061_row11_col4" class="data row11 col4" >0.200000</td>
#       <td id="T_51061_row11_col5" class="data row11 col5" >Iris-setosa</td>
#       <td id="T_51061_row11_col6" class="data row11 col6" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_51061_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_51061_row12_col0" class="data row12 col0" >13</td>
#       <td id="T_51061_row12_col1" class="data row12 col1" >4.800000</td>
#       <td id="T_51061_row12_col2" class="data row12 col2" >3.000000</td>
#       <td id="T_51061_row12_col3" class="data row12 col

# %%
data.isnull()
# Out:
#         id  sepallengthCm  sepalwedithCm  petallength  petalwidth  class  \
# 0    False          False          False        False       False  False
# 1    False          False          False        False       False  False
# 2    False          False          False        False       False  False
# 3    False          False          False        False       False  False
# 4    False          False          False        False       False  False
# ..     ...            ...            ...          ...         ...    ...
# 145  False          False          False        False       False  False
# 146  False          False          False        False       False  False
# 147  False          False          False        False       False  False
# 148  False          False          False        False       False  False
# 149  False          False          False        False       False  False
#
#      total_values
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 145         False
# 146         False
# 147         False
# 148         False
# 149         False
#
# [150 rows x 7 columns]

# %%
data.describe()
# Out:
#                id  sepallengthCm  sepalwedithCm  petallength  petalwidth  \
# count  150.000000     150.000000     150.000000   150.000000  150.000000
# mean    75.500000       5.843333       3.054000     3.758667    1.198667
# std     43.445368       0.828066       0.433594     1.764420    0.763161
# min      1.000000       4.300000       2.000000     1.000000    0.100000
# 25%     38.250000       5.100000       2.800000     1.600000    0.300000
# 50%     75.500000       5.800000       3.000000     4.350000    1.300000
# 75%    112.750000       6.400000       3.300000     5.100000    1.800000
# max    150.000000       7.900000       4.400000     6.900000    2.500000
#
#        total_values
# count    150.000000
# mean      13.854667
# std        3.128149
# min        8.400000
# 25%       10.700000
# 50%       14.300000
# 75%       16.250000
# max       20.400000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             150 non-null    int64
#  1   sepallengthCm  150 non-null    float64
#  2   sepalwedithCm  150 non-null    float64
#  3   petallength    150 non-null    float64
#  4   petalwidth     150 non-null    float64
#  5   class          150 non-null    object
#  6   total_values   150 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 8.3+ KB

# %%
plt.figure(figsize = (10,7))
x = data["sepallengthCm"]

plt.hist(x, bins = 20, color = "green")
plt.xlabel("sepal_length_cm")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize = (10,7))
x = data.petallength

plt.hist(x, bins = 20, color = "green")
plt.title("petal length in Cm")
plt.xlabel("petal_length_cm")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize = (10,7))
x = data.petalwidth

plt.hist(x, bins = 20, color = "green")
plt.title("petal width in Cm")
plt.xlabel("petal_width_cm")
plt.ylabel("Count")
plt.show()

# %%
new_data = data[["sepallengthCm", "petallength", "petalwidth"]]
print(new_data.head())
# Out:
#    sepallengthCm  petallength  petalwidth
# 0            5.1          1.4         0.2
# 1            4.9          1.4         0.2
# 2            4.7          1.3         0.2
# 3            4.6          1.5         0.2
# 4            5.0          1.4         0.2

# %%
plt.figure(figsize = (10,7))
new_data.boxplot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import matplotlib.pyplot as plt
iris = pd.read_csv("C:\\Users\HP\\Desktop\\LGMVIP Task1\\iris.csv")

plt.plot(iris.id, iris["sepallength"], "r--")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
iris.plot(kind="scatter",
         x= "sepallength",
         y= "petallength")
plt.grid()

# %%
import seaborn as sns
g = sns.pairplot(data, hue="class")
